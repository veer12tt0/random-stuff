# %%
def tutorial():
    print(f"{BG_WHITE}{BLUE}{BOLD}This is the tutorial for this game.{RESET}")
    print(f"{BG_WHITE}{BLUE}Since, you can not add controlls in vanilla python, This game will be controlled with a few commands that It will be easy to understand, use and memorise. ;-){RESET}")
    print(f"{BG_WHITE}{BLUE}The commands are as follows:{RESET}")
    print(f"{BG_WHITE}{BLUE}1. load - If you have a saved game in JSON format.{RESET}")
    print(f"{BG_WHITE}{BLUE}2. save - Saves your current game progress.{RESET}")
    print(f"{BG_WHITE}{BLUE}3. catch - If you want to catch a monster.{RESET}")
    print(f"{BG_WHITE}{BLUE}4. buy - Can only be used in stores to buy stuff.{RESET}")
    print(f"{BG_WHITE}{BLUE}5. info - To view your player info.{RESET}")
    print(f"{BG_WHITE}{BLUE}6. party - To see which monsters are currently usable.{RESET}")
    print(f"{BG_WHITE}{BLUE}7. attack - To attack your enemy.{RESET}")
    print(f"{BG_WHITE}{BLUE}8. go - To go to buildings.{RESET}")
    print(f"{BG_WHITE}{BLUE}9. go_to - To travel to a different place on the map.{RESET}")
    print(f"{BG_WHITE}{BLUE}10. active - To see the current active monster.{RESET}")
    print(f"{BG_WHITE}{BLUE}11. activate - To change the current active monster.{RESET}")
    print(f"{BG_WHITE}{BLUE}12. battle - To have a battle with other trainers and gym leaders.{RESET}")
    print(f"{BG_WHITE}{BLUE}13. item_info - To know the quantity of items you have.{RESET}")
    print(f"{BG_WHITE}{BLUE}14. help/tutorial - To look at the commands again.{RESET}")

tutorial()
# Out:
# This is the tutorial for this game.
# Since, you can not add controlls in vanilla python, This game will be controlled with a few commands that It will be easy to understand, use and memorise. ;-)
# The commands are as follows:
# 1. load - If you have a saved game in JSON format.
# 2. save - Saves your current game progress.
# 3. catch - If you want to catch a monster.
# 4. buy - Can only be used in stores to buy stuff.
# 5. info - To view your player info.
# 6. party - To see which monsters are currently usable.
# 7. attack - To attack your enemy.
# 8. go - To go to buildings.
# 9. go_to - To travel to a different place on the map.
# 10. active - To see the current active monster.
# 11. activate - To change the current active monster.
# 12. battle - To have a battle with other trainers and gym leaders.
# 13. item_info - To know the quantity of items you have.
# 14. help/tutorial - To look at the commands again.

# %%
# --Styling--
RED     = "\033[31m"
GREEN   = "\033[32m"
YELLOW  = "\033[33m"
BLUE    = "\033[34m"
ITALIC = "\033[3m"
UNDERLINE = "\033[4m"
RESET = "\033[0m"
BOLD = "\033[1m"
BG_WHITE   = "\033[47m"

# --Data--

# Game variables
crnt_city = ""
money = 0
mons_hp = 0
mons_evl_hp = 0

# Game lists
Cities = ["Vatica", "Nethans", "Luna", "Suncity"]

# Game dictionaries
Gym_won = {
    "Vatica": False,
    "Nethans": False,
    "Luna": False,
    "Suncity": False
}

plyr_info = {
    "name": "",
    "money": 0,
    "team": [],
    "gym_won": Gym_won
}

item_quantity = {
    "potion": 0,
    "disk_space": 0,
}

item_price = {
    "potion": 10,
    "disk_space": 20
}

monster_bluprint = {
        "megmamon": {
        "name": "megmamon",
        "type": "Fire",
        "base_hp": random.randint(20, 25),
        "base_atk": random.randint(5, 10)
    },
    "splashermon": {
        "name": "splashermon",
        "type": "Water",
        "base_hp": random.randint(25, 30),
        "base_atk": random.randint(2, 10)
    },
    "bailsmon": {
        "name": "bailsmon",
        "type": "Grass",
        "base_hp": random.randint(25, 35),
        "base_atk": random.randint(2, 5)
    }
}

encountered_monster = {
    
}

monster_i_have = {

}

active_monster = {

}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 52
#      48 monster_bluprint = {
#      49         "megmamon": {
#      50         "name": "megmamon",
#      51         "type": "Fire",
# ---> 52         "base_hp": random.randint(20, 25),
#      53         "base_atk": random.randint(5, 10)
#      54     },
#      55     "splashermon": {
#
# NameError: name 'random' is not defined
